# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('neet_data.csv')

# %%
#QUESTION 
print("column information")
data.info()
# Out:
# column information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47381 entries, 0 to 47380
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created_at           47381 non-null  object
#  1   retweet_count        47381 non-null  int64
#  2   source               47362 non-null  object
#  3   user_id              47381 non-null  int64
#  4   user_name            47380 non-null  object
#  5   user_description     36510 non-null  object
#  6   user_follower_count  47381 non-null  int64
#  7   user_friends_count   47381 non-null  int64
#  8   user_location        26247 non-null  object
#  9   user_verified        47381 non-null  bool
#  10  user_url             9280 non-null   object
#  11  tweet                47381 non-null  object
#  12  length_of_tweet      47381 non-null  int64
# dtypes: bool(1), int64(5), object(7)
# memory usage: 4.4+ MB

# %%
#QUESTION 2
print("Total number of rows and columns: ")
data.shape
# Out:
# Total number of rows and columns:
# (47381, 13)

# %%
data.head()
# Out:
#             created_at  retweet_count               source  \
# 0  2020-10-31 14:10:28            141  Twitter for Android
# 1  2020-10-31 14:10:11              1   Twitter for iPhone
# 2  2020-10-31 14:09:48            141      Twitter Web App
# 3  2020-10-31 14:09:41            141  Twitter for Android
# 4  2020-10-31 14:09:22              0  Twitter for Android
#
#                user_id     user_name  \
# 0  1250294694937915394          Rumi
# 1             57059492    Tom Bewick
# 2           1016022678      Lemonade
# 3  1085818329816883201       The Rus
# 4  1227501071490113537  Sakshi Yadav
#
#                                     user_description  user_follower_count  \
# 0                                                NaN                   14
# 1  Proud dad of three & cat, @SussexCCC fan. CEO ...                 2314
# 2  Wisdom is knowing the right path to take, Inte...                  285
# 3                                                NaN                  147
# ...

# %%
#QUESTION 3
data.sort_values(by='retweet_count' ,ascending=False,inplace=True)
data
# Out:
#                 created_at  retweet_count               source  \
# 32860  2020-11-08 05:30:01         614304   Twitter for iPhone
# 33262  2020-11-07 21:52:54         581097  Twitter for Android
# 35111  2020-11-06 14:20:33         381458      Twitter Web App
# 32585  2020-11-08 07:19:02         204348   Twitter for iPhone
# 38044  2020-11-04 18:19:13         192350   Twitter for iPhone
# ...                    ...            ...                  ...
# 47347  2020-10-30 15:48:45              0        WordPress.com
# 47348  2020-10-30 15:48:43              0        WordPress.com
# 47349  2020-10-30 15:48:42              0        WordPress.com
# 47351  2020-10-30 15:46:53              0      Twitter Web App
# 47332  2020-10-30 15:53:51              0  Twitter for Android
#
#                    user_id                                          user_name  \
# 32860  1024658968394625024               \xe3\x81\xb2\xe3\x81\x88\xe3\x81\xa3
# ...

# %%
#QUESTION 4
data.loc[data['retweet_count']==data['retweet_count'].max()]
# Out:
#                 created_at  retweet_count              source  \
# 32860  2020-11-08 05:30:01         614304  Twitter for iPhone
#
#                    user_id                             user_name  \
# 32860  1024658968394625024  \xe3\x81\xb2\xe3\x81\x88\xe3\x81\xa3
#
#                                         user_description  user_follower_count  \
# 32860  \xe3\x85\xa4\xe3\x82\xa2\xe3\x82\xa4\xe3\x82\x...                   62
#
#        user_friends_count user_location  user_verified  \
# 32860                 115           NaN          False
#
#                       user_url  \
# 32860  https://t.co/cHZdP4uOdu
#
#                                                    tweet  length_of_tweet
# 32860  RT @JoeBiden: America, I\xe2\x80\x99m honored ...              140

# %%
#QUESTION 5
df=data.head(10)

# %%
s=df['retweet_count'].sum()
print("TOP 10 retweet sum is  ",s)
# Out:
# TOP 10 retweet sum is   2652225

# %%
data[data['source']=='Twitter for Android']
# Out:
#                 created_at  retweet_count               source  \
# 33262  2020-11-07 21:52:54         581097  Twitter for Android
# 16277  2020-10-25 14:14:37         137480  Twitter for Android
# 37640  2020-11-05 04:09:52         137367  Twitter for Android
# 14527  2020-10-26 13:28:21         129080  Twitter for Android
# 38417  2020-11-04 14:15:01          95921  Twitter for Android
# ...                    ...            ...                  ...
# 47340  2020-10-30 15:49:57              0  Twitter for Android
# 47344  2020-10-30 15:48:54              0  Twitter for Android
# 47346  2020-10-30 15:48:45              0  Twitter for Android
# 29     2020-10-31 13:59:01              0  Twitter for Android
# 47332  2020-10-30 15:53:51              0  Twitter for Android
#
#                    user_id                                          user_name  \
# 33262  1099388669448867842                           Neet\xf0\x9f\x83\x8fPeet
# ...

# %%
#QUESTION 6
data[data['source']=='Twitter for Android'].shape[0]
# Out:
# 28850

# %%
data[data.loc[:,'source']=='Twitter for Android'].retweet_count.sum()
# Out:
# np.int64(9386742)

# %%
#QUESTION 7
data.loc[data['user_follower_count']==data['user_follower_count'].max(),['user_name','user_location']]
# Out:
#       user_name user_location
# 44367      NDTV         India
# 44355      NDTV         India
# 44436      NDTV         India
# 44424      NDTV         India

# %%
#QUESTION 8
data['followers_friends_ratio']=data['user_follower_count']/data['user_friends_count']
data
# Out:
#                 created_at  retweet_count               source  \
# 32860  2020-11-08 05:30:01         614304   Twitter for iPhone
# 33262  2020-11-07 21:52:54         581097  Twitter for Android
# 35111  2020-11-06 14:20:33         381458      Twitter Web App
# 32585  2020-11-08 07:19:02         204348   Twitter for iPhone
# 38044  2020-11-04 18:19:13         192350   Twitter for iPhone
# ...                    ...            ...                  ...
# 47347  2020-10-30 15:48:45              0        WordPress.com
# 47348  2020-10-30 15:48:43              0        WordPress.com
# 47349  2020-10-30 15:48:42              0        WordPress.com
# 47351  2020-10-30 15:46:53              0      Twitter Web App
# 47332  2020-10-30 15:53:51              0  Twitter for Android
#
#                    user_id                                          user_name  \
# 32860  1024658968394625024               \xe3\x81\xb2\xe3\x81\x88\xe3\x81\xa3
# ...

# %%
#QUESTION 9
data.isnull().sum()
# Out:
# created_at                     0
# retweet_count                  0
# source                        19
# user_id                        0
# user_name                      1
# user_description           10871
# user_follower_count            0
# user_friends_count             0
# user_location              21134
# user_verified                  0
# user_url                   38101
# tweet                          0
# length_of_tweet                0
# followers_friends_ratio      147
# dtype: int64

# %%
#QUESTION 10
data.user_description.fillna('Twitter User ', inplace=True)
data
# Out:
#                 created_at  retweet_count               source  \
# 32860  2020-11-08 05:30:01         614304   Twitter for iPhone
# 33262  2020-11-07 21:52:54         581097  Twitter for Android
# 35111  2020-11-06 14:20:33         381458      Twitter Web App
# 32585  2020-11-08 07:19:02         204348   Twitter for iPhone
# 38044  2020-11-04 18:19:13         192350   Twitter for iPhone
# ...                    ...            ...                  ...
# 47347  2020-10-30 15:48:45              0        WordPress.com
# 47348  2020-10-30 15:48:43              0        WordPress.com
# 47349  2020-10-30 15:48:42              0        WordPress.com
# 47351  2020-10-30 15:46:53              0      Twitter Web App
# 47332  2020-10-30 15:53:51              0  Twitter for Android
#
#                    user_id                                          user_name  \
# 32860  1024658968394625024               \xe3\x81\xb2\xe3\x81\x88\xe3\x81\xa3
# ...

# %%
#QUESTION 11
data.dropna(axis=1,inplace=True)
data
# Out:
#                 created_at  retweet_count              user_id  \
# 32860  2020-11-08 05:30:01         614304  1024658968394625024
# 33262  2020-11-07 21:52:54         581097  1099388669448867842
# 35111  2020-11-06 14:20:33         381458           2578241503
# 32585  2020-11-08 07:19:02         204348  1103362192169189376
# 38044  2020-11-04 18:19:13         192350             54249914
# ...                    ...            ...                  ...
# 47347  2020-10-30 15:48:45              0  1259781444185944066
# 47348  2020-10-30 15:48:43              0            376197627
# 47349  2020-10-30 15:48:42              0  1260150415146070016
# 47351  2020-10-30 15:46:53              0  1222115365880074240
# 47332  2020-10-30 15:53:51              0  1146318087475437568
#
#                                         user_description  user_follower_count  \
# 32860  \xe3\x85\xa4\xe3\x82\xa2\xe3\x82\xa4\xe3\x82\x...                   62
# ...

# %%
#QUESTION 12
data.insert(2,'is_allow' ,True)
data
# Out:
#                 created_at  retweet_count  is_allow              user_id  \
# 32860  2020-11-08 05:30:01         614304      True  1024658968394625024
# 33262  2020-11-07 21:52:54         581097      True  1099388669448867842
# 35111  2020-11-06 14:20:33         381458      True           2578241503
# 32585  2020-11-08 07:19:02         204348      True  1103362192169189376
# 38044  2020-11-04 18:19:13         192350      True             54249914
# ...                    ...            ...       ...                  ...
# 47347  2020-10-30 15:48:45              0      True  1259781444185944066
# 47348  2020-10-30 15:48:43              0      True            376197627
# 47349  2020-10-30 15:48:42              0      True  1260150415146070016
# 47351  2020-10-30 15:46:53              0      True  1222115365880074240
# 47332  2020-10-30 15:53:51              0      True  1146318087475437568
#
#                                         user_description  user_follower_count  \
# ...

# %%
#QUESTION 13
data.drop('tweet',axis=1,inplace=True)
data
# Out:
#                 created_at  retweet_count  is_allow              user_id  \
# 32860  2020-11-08 05:30:01         614304      True  1024658968394625024
# 33262  2020-11-07 21:52:54         581097      True  1099388669448867842
# 35111  2020-11-06 14:20:33         381458      True           2578241503
# 32585  2020-11-08 07:19:02         204348      True  1103362192169189376
# 38044  2020-11-04 18:19:13         192350      True             54249914
# ...                    ...            ...       ...                  ...
# 47347  2020-10-30 15:48:45              0      True  1259781444185944066
# 47348  2020-10-30 15:48:43              0      True            376197627
# 47349  2020-10-30 15:48:42              0      True  1260150415146070016
# 47351  2020-10-30 15:46:53              0      True  1222115365880074240
# 47332  2020-10-30 15:53:51              0      True  1146318087475437568
#
#                                         user_description  user_follower_count  \
# ...

# %%
#QUESTION 14
df['created_at'] = df['created_at'].astype(str)
df['month'] = df['created_at'].str.split('-').str[1]
df['year'] = df['created_at'].str.split('-').str[0]
print("Month and Year: ")
df[['created_at', 'month', 'year']].head()
# Out:
# Month and Year:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_10684\3992556262.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['created_at'] = df['created_at'].astype(str)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_10684\3992556262.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df['created_at'].str.split('-').str[1]
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_10684\3992556262.py:4: SettingWithCopyWarning:
# ...
